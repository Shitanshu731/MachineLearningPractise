# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      --------- --------------------------- 41.0/165.9 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 165.9/165.9 kB 2.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    -------------------------------------- - 286.7/294.9 kB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 294.9/294.9 kB 9.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 11.1 MB/s eta 0:00:01
#    --- ------------------------------------ 0.7/8.0 MB 7.7 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.9/8.0 MB 6.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/8.0 MB 5.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/8.0 MB 5.9 MB/s eta 0:00:02
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dataset = pd.read_csv("Electric_Vehicle_Population_Data.csv")

# %%
dataset.head()
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA      98112.0        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA      98953.0        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA      98031.0        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA      98012.0        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA      98908.0        2022  TOYOTA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# 1        330E  Plug-in Hybrid Electric Vehicle (PHEV)
# 2        LEAF          Battery Electric Vehicle (BEV)
# 3     MODEL S          Battery Electric Vehicle (BEV)
# 4  RAV4 PRIME  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             270
# ...

# %%
dataset.shape
# Out:
# (191407, 17)

# %%
dataset.isnull()
# Out:
#         VIN (1-10)  County   City  State  Postal Code  Model Year   Make  \
# 0            False   False  False  False        False       False  False
# 1            False   False  False  False        False       False  False
# 2            False   False  False  False        False       False  False
# 3            False   False  False  False        False       False  False
# 4            False   False  False  False        False       False  False
# ...            ...     ...    ...    ...          ...         ...    ...
# 191402       False   False  False  False        False       False  False
# 191403       False   False  False  False        False       False  False
# 191404       False   False  False  False        False       False  False
# 191405       False   False  False  False        False       False  False
# 191406       False   False  False  False        False       False  False
#
#         Model  Electric Vehicle Type  \
# 0       False                  False
# ...

# %%
dataset.head(10)
# Out:
#    VIN (1-10)     County     City State  Postal Code  Model Year    Make  \
# 0  5YJSA1E22K       King  Seattle    WA      98112.0        2019   TESLA
# 1  3MW39FS05R     Yakima   Zillah    WA      98953.0        2024     BMW
# 2  1N4AZ0CP0F       King     Kent    WA      98031.0        2015  NISSAN
# 3  5YJSA1H20F  Snohomish  Bothell    WA      98012.0        2015   TESLA
# 4  JTMAB3FV1N     Yakima   Yakima    WA      98908.0        2022  TOYOTA
# 5  5YJ3E1EB6K       King  Redmond    WA      98052.0        2019   TESLA
# 6  5YJ3E1EB0J   Thurston     Yelm    WA      98597.0        2018   TESLA
# 7  3FA6P0SU8D     Kitsap  Poulsbo    WA      98370.0        2013    FORD
# 8  5YJSA1E21H       King  Redmond    WA      98052.0        2017   TESLA
# 9  5YJ3E1EA4J  Snohomish  Bothell    WA      98012.0        2018   TESLA
#
#         Model                   Electric Vehicle Type  \
# 0     MODEL S          Battery Electric Vehicle (BEV)
# ...

# %%
dataset.isnull()
# Out:
#         VIN (1-10)  County   City  State  Postal Code  Model Year   Make  \
# 0            False   False  False  False        False       False  False
# 1            False   False  False  False        False       False  False
# 2            False   False  False  False        False       False  False
# 3            False   False  False  False        False       False  False
# 4            False   False  False  False        False       False  False
# ...            ...     ...    ...    ...          ...         ...    ...
# 191402       False   False  False  False        False       False  False
# 191403       False   False  False  False        False       False  False
# 191404       False   False  False  False        False       False  False
# 191405       False   False  False  False        False       False  False
# 191406       False   False  False  False        False       False  False
#
#         Model  Electric Vehicle Type  \
# 0       False                  False
# ...

# %% [markdown]
# Find the Sum of All Null values if any for each Column

# %%
dataset.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 4
# City                                                   4
# State                                                  0
# Postal Code                                            4
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 414
# DOL Vehicle ID                                         0
# Vehicle Location                                       8
# Electric Utility                                       4
# ...

# %% [markdown]
# ## Using SNS(Seaborn) and matplotlib

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [markdown]
# Removing the column with highest Null Values

# %%
dataset.drop(columns=["Legislative District"],inplace=True)

# %%
dataset.shape
# Out:
# (191407, 16)

# %%
dataset.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               4
# City                                                 4
# State                                                0
# Postal Code                                          4
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# DOL Vehicle ID                                       0
# Vehicle Location                                     8
# Electric Utility                                     4
# 2020 Census Tract                                    4
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [markdown]
# ## Delete all the Missing Value i.e will be deleting all the rows having null values using "dropna()" function

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %% [markdown]
# # Now the heatmap will be Red in Color beacause there will be no null values

# %%
sns.heatmap(dataset.isnull()) 
plt.show()

# %% [markdown]
# ### Check how musch data(or rows) we have lost

# %%
dataset.shape
# Out:
# (191399, 16)

# %%
((191407 - 191399)/191399) *100
# Out:
# 0.004179750155434459

# %% [markdown]
# ### From the Above Calculation , we Have lose 0.004 % data

# %% [markdown]
# So now there will be 0 Null Values

# %%
dataset.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64
